# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo

# %%
# %cd /content/drive/MyDrive/yolov5
# Out:
# /content/drive/MyDrive/yolov5

# %%
import torch
import os
from IPython.display import Image, clear_output  
import cv2
import json
import glob
from google.colab.patches import cv2_imshow

# %%
# %pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 596 kB 32.9 MB/s

# %%
image = cv2.imread('/content/drive/MyDrive/walrus_dataset/images/104.jpg')
js = json.load(open('/content/drive/MyDrive/walrus_dataset/markup/104.json'))

# %%
# bboxes -> center points
# names = glob.glob('/content/drive/MyDrive/walrus_dataset/val/*')
# for path in names:

#   image = cv2.imread(path)
#   js = json.load(open(path.replace('.jpg', '.json').replace('val', 'markup')))
#   height, width, _ = image.shape
#   f = open(path.replace('.jpg', '.txt'), "w")
#   for i in js:
#     b = i['bbox']
#     b_center_x = (b[0] + b[2] / 2 ) / width
#     b_center_y = (b[1] + b[3] / 2) / height
#     b_width    = b[2] / width
#     b_height   = b[3] / height
#     f.write(f'0 {b_center_x} {b_center_y} {b_width} {b_height}\n')

#   f.close()

# %%
# !python train.py --img 640 --batch 16 --epochs 2000 --data /content/drive/MyDrive/yolov5/walrus.yaml --cache --cfg /content/drive/MyDrive/yolov5/models/hub/yolov5x6.yaml
# Out:
# train: weights=yolov5s.pt, cfg=/content/drive/MyDrive/yolov5/models/hub/yolov5x6.yaml, data=/content/drive/MyDrive/yolov5/walrus.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=2000, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 196 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-37-g3f634d4 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/best.pt --img 1280 --conf 0.8 --source /content/drive/MyDrive/walrus_dataset/val
# Out:
# detect: weights=['/content/drive/MyDrive/best.pt'], source=/content/drive/MyDrive/walrus_dataset/val, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.8, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-37-g3f634d4 torch 1.11.0+cu113 CPU
#
# Fusing layers...
# Model Summary: 444 layers, 86173414 parameters, 0 gradients, 204.0 GFLOPs
# image 1/30 /content/drive/MyDrive/walrus_dataset/val/104.jpg: 736x1280 183 walruss, Done. (7.516s)
# image 2/30 /content/drive/MyDrive/walrus_dataset/val/11.jpg: 736x1280 50 walruss, Done. (7.341s)
# image 3/30 /content/drive/MyDrive/walrus_dataset/val/113.jpg: 736x1280 315 walruss, Done. (7.336s)
# ...
